# %% [markdown]
# # Import Libraries and Dataframes

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Create path
path = "/Users/charlottelin/Documents/06-2025 Instacart Basket Analysis"

# %%
# Import ords_prods_merge
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
# Check dataframe
ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             0   2539329        1             1                   2
# 2             0   2539329        1             1                   2
# 3             0   2539329        1             1                   2
# 4             0   2539329        1             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge  Unnamed: 0_y                             product_name  \
# ...

# %%
# Drop the unnamed column
ords_prods_merge = ords_prods_merge.drop(columns=['Unnamed: 0_x'])

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#    Unnamed: 0_y                             product_name  aisle_id  \
# ...

# %% [markdown]
# # Work with Data Subset / Memory Control

# %%
#Limit dataframe to a subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 16)

# %% [markdown]
# # Create Price Label

# %%
# Create the 'price_label' for filtering products by price range
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %% [markdown]
# # Add the new 'price_range' column

# %%
# Apply 'price_label' to dataframe
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/t0/dyr0vh9d10q4v8pztlwjgtkh0000gn/T/ipykernel_84095/2429282223.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    673340
# Low-range product    314392
# High range            12268
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 25.0

# %% [markdown]
# # If-Statements with loc() fucntion

# %%
# Create conditions - different cells for each condition
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/t0/dyr0vh9d10q4v8pztlwjgtkh0000gn/T/ipykernel_84095/1569627056.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Count the values in each prices
df['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     673340
# Low-range product     314392
# High-range product     12268
# Name: count, dtype: int64

# %% [markdown]
# # Apply loc() function to the entire dataframe

# %%
# Create conditions for the entire dataframe
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Count the values in prices
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21865987
# Low-range product     10126321
# High-range product      412551
# Name: count, dtype: int64

# %%
ords_prods_merge['prices'].max()
# Out:
# 25.0

# %% [markdown]
# # If-Statements with For loops

# %%
#Find out which days most orders take place
ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %% [markdown]
# ### Notes from Project Brief: 0 = Saturday = the busiest day; 4 = Wednesday = the least busy day

# %% [markdown]
# # Create new column 'Busiest Day' with 3 values

# %%
#Use for-loop to create a new 'busiest day' column with the values of 'busiest day', 'least busy' and 'regularly busy'
result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
# Check the loop result
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %% [markdown]
# # Integrate "busiest day" in ords_prods_merge dataframe

# %%
ords_prods_merge['busiest_day'] = result

# %%
# Check results
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# # Additional Tasks in Achievement 4.7

# %% [markdown]
# ## Step 2 - Busiest Days & Slowest Days

# %%
# Use for-loop to create the conditions for busiest and slowest days
results = []

for value in ords_prods_merge["orders_day_of_week"]:
    if value in (0, 1):
        results.append("Busiest days")
    elif value in(3, 4):
        results.append("Slowest days")
    else:
        results.append("Regular days")

# %%
# Check results
results
# Out:
# ['Regular days',
#  'Regular days',
#  'Regular days',
#  'Regular days',
#  'Regular days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regular days',
#  'Regular days',
#  'Regular days',
#  'Regular days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
# ...

# %%
# Create a new 'busiest_day' column
ords_prods_merge['busiest_days'] = results

# %% [markdown]
# ## Step 3 - Check new column for accuracy

# %%
ords_prods_merge['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regular days    12916111
# Busiest days    11864412
# Slowest days     7624336
# Name: count, dtype: int64

# %%
ords_prods_merge.shape[0]
# Out:
# 32404859

# %% [markdown]
# ### Observation: Regular days are the most abundant, suggesting that demand is more even distributed than expected. Busiest days are still significant which indicates attention should be focused on weekends. Slowest days are noticebaly lower than the others, which can inform employee placement or store maintenance decisions. Also, the total number matches what is expected if the column was applied to the entire dataset.

# %% [markdown]
# ## Step 4 - Busiest Hour of the Day

# %%
# Rank hours from most to least busy based on order frequency
ords_prods_merge['order_hour_of_day'].value_counts(dropna=False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %% [markdown]
# ### Labeling strategy: top 8 busiest hours = "Most Orders"; bottom 8 least busy hours = "Fewest Orders"; middle 8 hours = "Average Orders".

# %%
# Assign hour groups
results_hours = []

for value in ords_prods_merge["order_hour_of_day"]:
    if value in (10, 11, 14, 15, 13, 12, 16, 9):
        results_hours.append("Most Orders")
    elif value in (17, 8, 18, 19, 20, 7, 21, 22):
        results_hours.append("Average Orders")
    else:
        results_hours.append("Fewest Orders")

# %%
# Create new column 'busiest_period_of_day'
ords_prods_merge['busiest_period_of_day'] = results_hours

# %% [markdown]
# ## Step 5 - Frequency of new column

# %%
ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most Orders       21118071
# Average Orders     9997651
# Fewest Orders      1289137
# Name: count, dtype: int64

# %%
ords_prods_merge.shape[0]
# Out:
# 32404859

# %% [markdown]
# ### The sum of the new column is as expected when applied to the entire dataset.

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#    Unnamed: 0_y                             product_name  aisle_id  \
# ...

# %%
## Step 7 - Export updated dataframe as new pickle
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge_extra_columns.pkl'))
